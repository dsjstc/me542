# %%
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#InteractiveShell.ast_node_interactivity = "last"
from importlib import reload
import pandas as pd
# %load_ext autoreload
# %autoreload 2
pd.set_option("display.precision",2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Storage tank
#
# The storage tank model is oversimplified.  I've simply assumed that I can't get any heat out of when the tank temperature is below 35.
#
# A better model would be to determine whether the hour's heating load could be met based on the delta-T between the tank water and the house RT.

# %%
# Apply the heating model and run solar.
import bau
df = pd.read_pickle("irradiance2014.pickle")['2013']
b = bau.BAU(df)
b.apply()
df = b.df

# Solar
import hsolar
hsol = hsolar.HSolar(df)
hsol.apply()
df = hsol.df

# %%
# Initialize the tank.
from tank import *
tank = Tank(df)
tank.iterTankAdd()

# %%
df[['ttank','OAT','tankextract']].plot(figsize=(12,8),
                            alpha=.7,
                        secondary_y='OAT')
