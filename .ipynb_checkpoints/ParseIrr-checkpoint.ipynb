# %%
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#%load_ext autoreload
# %autoreload 2

import pandas as pd

# %%
from loadirr import *
irr=loadirr()

# %%
#kp = pd.read_pickle('irradiance.pickle')
#df = pd.read_pickle('full_irradiance.pickle')
irr.nlargest(5,columns=['IrrDrN'])
# Out:
#                         IrrET    IrrGlH    IrrDrN    IrrDfH  Pressure   OAT  \
# Dtime
# 2013-04-14 12:00:00  1.036389  0.845000  0.926944  0.136944    101.46   8.0
# 2013-03-31 12:00:00  0.960278  0.767500  0.926667  0.116667    101.58  10.8
# 2013-03-28 12:00:00  0.942222  0.754444  0.926389  0.117500    101.82  10.1
# 2013-03-25 12:00:00  0.923333  0.738889  0.925833  0.116111    101.67   9.2
# 2013-04-15 12:00:00  1.041111  0.847222  0.925000  0.136944    101.74   9.0
#
#                      Dewpoint  WindDir  Wind_kmh     sunalt       sunaz
# Dtime
# 2013-04-14 12:00:00       1.9      340      6.12  47.445493  151.676515
# 2013-03-31 12:00:00       6.2      310     11.16  42.174958  152.664809
# 2013-03-28 12:00:00       6.8      350      6.12  40.997580  152.844020
# 2013-03-25 12:00:00       4.0       80      3.96  39.810424  153.017388
# 2013-04-15 12:00:00       4.4      330     16.92  47.802606  151.593044
