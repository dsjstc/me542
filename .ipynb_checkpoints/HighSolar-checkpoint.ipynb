# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#InteractiveShell.ast_node_interactivity = "last"
from importlib import reload
import pandas as pd
# %autoreload 2
pd.set_option("display.precision",2)

# %%
import pandas as pd
df = pd.read_pickle("irradiance2014.pickle")['2013']

# Apply the heating model
import bau
b = bau.BAU(df)
b.apply()
df = b.df

import hsolar
reload(hsolar)

hsol = hsolar.HSolar(df)
hsol.apply()
df = hsol.df
# Out:
# <module 'hsolar' from '/home/at/Dropbox/Exergy/Project/HouseModels/hsolar.py'>

# %%
d11 = df[(df.index.year==2013)&(df.index.month==11)].copy()
h11 = hsolar.HSolar(d11)
x = h11.collAndSave(45)

d12 = df[(df.index.year==2013)&(df.index.month==12)].copy()
h12 = hsolar.HSolar(d12)
h12.collAndSave(35)
# Out:
# 45.09539615750226

# %%
import matplotlib.pyplot as plt
pdf['cumsav']=(df.hload-df.rload).cumsum().copy()
pdf['prroll'] = df.prload.rolling(24).mean()

irrNZ = df.IrrDrN[df.IrrDrN>.1] 
irrNZdt = df.IrrDrN[df.sunalt>0]
pdf['irrNZr'] = irrNZ.rolling(12).mean()
#pdf.drop('prload',axis=1,inplace=True)
pdf.plot(secondary_y='cumsav',alpha=.7,figsize=(15,8))

# %%
import pandas as pd
import bau
ir = pd.read_pickle("irradiance2014.pickle")

b = bau.BAU(ir)
b.apply()

fig, axe = plt.subplots(nrows=1, ncols=1,figsize=(8,8))

axe.set_ylabel("Consumption (kWh)")
h = ir.bcons.groupby(ir.index.month).sum().plot(ax=axe,label='Consumption',legend=True)
h = ir.IrrDrN.groupby(ir.index.month).sum().plot(ax=axe,secondary_y='IrrDrN',legend=True)
h.set_ylabel('Irradiance (kWh)')
axe.set_xlabel("Month")
# Out:
# Text(0,0.5,'Consumption (kWh)')
# Text(0,0.5,'Irradiance')
# Text(0.5,0,'Month')

# %%
df.columns
# Out:
# Index(['IrrET', 'IrrGlH', 'IrrDrN', 'IrrDfH', 'Pressure', 'OAT', 'Dewpoint',
#        'WindDir', 'Wind_kmh', 'sunalt', 'sunaz', 'rt', 'rtsp', 'exheat',
#        'hload', 'rload', 'bcons', 'cons', 'prload', 'dt', 'soleff',
#        'solanginc', 'normalfraction', 'solheat', 'normsav', 'sload', 'sav'],
#       dtype='object')
